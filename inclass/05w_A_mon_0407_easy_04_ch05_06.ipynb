# %% [markdown]
# <a href="https://colab.research.google.com/github/pcw11/2025-1-myclass-BDA/blob/main/inclass/05w_A_mon_0407_easy_04_ch05_06.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 05주 수업

# %% [markdown]
# ## p.116 / 05-3 파생변수 생성

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame({'var1': [4, 3, 8], 'var2' : [2, 6, 1]})
df
# Out:
#    var1  var2
# 0     4     2
# 1     3     6
# 2     8     1

# %%
df1= df.copy()
df1
# Out:
#    var1  var2
# 0     4     2
# 1     3     6
# 2     8     1

# %%
df1['var_sum'] = df1.var1 + df1.var2
df1
# Out:
#    var1  var2  var_sum
# 0     4     2        6
# 1     3     6        9
# 2     8     1        9

# %%
df1.var_sum2 = df1.var1 + df1.var2
df1
# Out:
#    var1  var2  var_sum
# 0     4     2        6
# 1     3     6        9
# 2     8     1        9

# %%
df1['var_sum'] = (df1.var1 + df1.var2) / 2
df1
# Out:
#    var1  var2  var_sum
# 0     4     2      3.0
# 1     3     6      4.5
# 2     8     1      4.5

# %%
df
# Out:
#    var1  var2
# 0     4     2
# 1     3     6
# 2     8     1

# %%
df1
# Out:
#    var1  var2  var_sum
# 0     4     2      3.0
# 1     3     6      4.5
# 2     8     1      4.5

# %%
df2 = df.copy()
df2
# Out:
#    var1  var2
# 0     4     2
# 1     3     6
# 2     8     1

# %%
df.sum()
# Out:
# var1    15
# var2     9
# dtype: int64

# %%
df2.sum(axis=0)
# Out:
# var1    15
# var2     9
# dtype: int64

# %%
df2.sum(axis=1)
# Out:
# 0    12
# 1    18
# 2    18
# dtype: int64

# %%
df2['my_sum'] = df2.sum(axis=1)
df2
# Out:
#    var1  var2  my_sum
# 0     4     2       6
# 1     3     6       9
# 2     8     1       9

# %%
df2['my_sum'] = df2.sum(axis='columns')
df2
# Out:
#    var1  var2  my_sum
# 0     4     2      12
# 1     3     6      18
# 2     8     1      18

# %%
df2[["var1", "var2"]]
# Out:
#    var1  var2
# 0     4     2
# 1     3     6
# 2     8     1

# %%
df1[['var1']]
# Out:
#    var1
# 0     4
# 1     3
# 2     8

# %%
df2['my_mean'] = df2[['var1', 'var2']].mean(axis='columns')
df2
# Out:
#    var1  var2  my_sum  my_mean
# 0     4     2      12      3.0
# 1     3     6      18      4.5
# 2     8     1      18      4.5

# %% [markdown]
# ## mpg 데이터
# #### // 시험 반드시 나옴

# %%
# !git clone https://github.com/ai7dnn/data
# Out:
# Cloning into 'data'...
# remote: Enumerating objects: 24, done.
# remote: Counting objects: 100% (24/24), done.
# remote: Compressing objects: 100% (22/22), done.
# remote: Total 24 (delta 4), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (24/24), 2.14 MiB | 6.15 MiB/s, done.
# Resolving deltas: 100% (4/4), done.

# %%
mpg =pd.read_csv('data/mpg.csv')
mpg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   manufacturer  234 non-null    object
#  1   model         234 non-null    object
#  2   displ         234 non-null    float64
#  3   year          234 non-null    int64
#  4   cyl           234 non-null    int64
#  5   trans         234 non-null    object
#  6   drv           234 non-null    object
#  7   cty           234 non-null    int64
#  8   hwy           234 non-null    int64
#  9   fl            234 non-null    object
#  10  category      234 non-null    object
# dtypes: float64(1), int64(4), object(6)
# memory usage: 20.2+ KB

# %%
mpg.sample(3)
# Out:
#     manufacturer               model  displ  year  cyl       trans drv  cty  \
# 208   volkswagen                 gti    2.0  1999    4    auto(l4)   f   19
# 129         jeep  grand cherokee 4wd    6.1  2008    8    auto(l5)   4   11
# 145       nissan              altima    3.5  2008    6  manual(m6)   f   19
#
#      hwy fl category
# 208   26  r  compact
# 129   14  p      suv
# 145   27  p  midsize

# %%
mpg['total'] = (mpg.cty + mpg.hwy) / 2
mpg.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl category  \
# 0         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 1         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 2         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 3         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 4         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact
#
#    total
# 0   23.5
# 1   25.0
# 2   25.5
# 3   25.5
# 4   21.0

# %%
mpg['mpg_mean'] = mpg[['cty', 'hwy']].mean(axis=1)
mpg.sample(3)
# Out:
#     manufacturer            model  displ  year  cyl       trans drv  cty  hwy  \
# 84          ford  f150 pickup 4wd    4.2  1999    6  manual(m5)   4   14   17
# 8           audi       a4 quattro    1.8  1999    4    auto(l5)   4   16   25
# 121      hyundai          tiburon    2.7  2008    6  manual(m5)   f   17   24
#
#     fl    category  total  mpg_mean
# 84   r      pickup   15.5      15.5
# 8    p     compact   20.5      20.5
# 121  r  subcompact   20.5      20.5

# %%
sum(mpg['total']) / len(mpg)
# Out:
# 20.14957264957265

# %%
mpg['total'].mean()
# Out:
# np.float64(20.14957264957265)

# %%
mpg.shape
# Out:
# (234, 13)

# %%
len(mpg)
# Out:
# 234

# %%
sum(mpg['total']) / mpg.shape[0]  ## 시험 문제 나올 가능성
# Out:
# 20.14957264957265

# %%
mpg.total.describe()
# Out:
# count    234.000000
# mean      20.149573
# std        5.050290
# min       10.500000
# 25%       15.500000
# 50%       20.500000
# 75%       23.500000
# max       39.500000
# Name: total, dtype: float64

# %%
mpg.total.describe()['mean']
# Out:
# np.float64(20.14957264957265)

# %%
mpg.total.describe()[1]
# Out:
# <ipython-input-36-b4aef9eccf3a>:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   mpg.total.describe()[1]
# np.float64(20.14957264957265)

# %%
mpg.total.plot.hist();

# %%
# !pip install koreanize-matplotlib
# Out:
# Requirement already satisfied: koreanize-matplotlib in /usr/local/lib/python3.11/dist-packages (0.1.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from koreanize-matplotlib) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->koreanize-matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->koreanize-matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->koreanize-matplotlib) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->koreanize-matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.11/dist-packages (from matplotlib->koreanize-matplotlib) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->koreanize-matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->koreanize-matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->koreanize-matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->koreanize-matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->koreanize-matplotlib) (1.17.0)

# %%
import koreanize_matplotlib

# %%
# %config InlineBackend.figure_format = 'retina'

# %%
mpg.total.plot(kind='hist', title='히스토그램');

# %% [markdown]
# ## np.where()

# %%
np.where(mpg.total >= 20, 'pass', 'fall')
# Out:
# array(['pass', 'pass', 'pass', 'pass', 'pass', 'pass', 'pass', 'pass',
#        'pass', 'pass', 'pass', 'pass', 'pass', 'pass', 'pass', 'fall',
#        'pass', 'fall', 'fall', 'fall', 'fall', 'fall', 'fall', 'pass',
#        'fall', 'pass', 'pass', 'fall', 'fall', 'fall', 'fall', 'fall',
#        'pass', 'pass', 'pass', 'pass', 'pass', 'pass', 'pass', 'fall',
#        'fall', 'pass', 'pass', 'fall', 'fall', 'fall', 'fall', 'fall',
#        'fall', 'fall', 'fall', 'fall', 'fall', 'fall', 'fall', 'fall',
#        'fall', 'fall', 'fall', 'fall', 'fall', 'fall', 'fall', 'fall',
#        'fall', 'fall', 'fall', 'fall', 'fall', 'fall', 'fall', 'fall',
#        'fall', 'fall', 'fall', 'fall', 'fall', 'fall', 'fall', 'fall',
#        'fall', 'fall', 'fall', 'fall', 'fall', 'fall', 'fall', 'fall',
#        'fall', 'fall', 'pass', 'pass', 'pass', 'pass', 'fall', 'fall',
#        'fall', 'fall', 'fall', 'pass', 'pass', 'pass', 'pass', 'pass',
#        'pass', 'pass', 'pass', 'pass', 'pass', 'pass', 'pass', 'pass',
#        'pass', 'pass', 'pass', 'pass', 'pass', 'pass', 'pass', 'pass',
#        'pass', 'pass', 'fall', 'fall', 'fall', 'fall', 'fall', 'fall',
#        'fall', 'fall', 'fall', 'fall', 'fall', 'fall', 'fall', 'fall',
#        'fall', 'fall', 'fall', 'fall', 'fall', 'pass', 'pass', 'pass',
#        'pass', 'pass', 'pass', 'pass', 'pass', 'pass', 'fall', 'fall',
#        'fall', 'fall', 'pass', 'pass', 'pass', 'pass', 'pass', 'pass',
#        'pass', 'pass', 'pass', 'pass', 'pass', 'pass', 'pass', 'pass',
#        'pass', 'pass', 'pass', 'pass', 'pass', 'fall', 'fall', 'fall',
#        'fall', 'fall', 'fall', 'pass', 'pass', 'pass', 'pass', 'pass',
#        'pass', 'pass', 'pass', 'pass', 'pass', 'pass', 'pass', 'pass',
#        'pass', 'pass', 'pass', 'pass', 'pass', 'pass', 'fall', 'fall',
#        'fall', 'fall', 'fall', 'fall', 'fall', 'fall', 'fall', 'pass',
#        'pass', 'pass', 'pass', 'pass', 'pass', 'pass', 'pass', 'pass',
#        'pass', 'pass', 'pass', 'fall', 'pass', 'pass', 'pass', 'pass',
#        'pass', 'pass', 'pass', 'pass', 'pass', 'pass', 'pass', 'pass',
#        'pass', 'pass'], dtype='<U4')

# %%
mpg['test'] = np.where(mpg.total >= 20, 'pass', 'fall')
mpg.sample(5)
# Out:
#     manufacturer              model  displ  year  cyl       trans drv  cty  \
# 55         dodge  dakota pickup 4wd    5.2  1999    8  manual(m5)   4   11
# 15          audi         a6 quattro    2.8  1999    6    auto(l5)   4   15
# 165       subaru        impreza awd    2.2  1999    4    auto(l4)   4   21
# 196       toyota            corolla    1.8  2008    4  manual(m5)   f   28
# 74          ford     expedition 2wd    4.6  1999    8    auto(l4)   r   11
#
#      hwy fl    category  total  mpg_mean  test
# 55    17  r      pickup   14.0      14.0  fall
# 15    24  p     midsize   19.5      19.5  fall
# 165   26  r  subcompact   23.5      23.5  pass
# 196   37  r     compact   32.5      32.5  pass
# 74    17  r         suv   14.0      14.0  fall

# %%
mpg['test'].value_counts()
# Out:
# test
# pass    128
# fall    106
# Name: count, dtype: int64

# %%
mpg['test'].unique()
# Out:
# array(['pass', 'fall'], dtype=object)

# %%
count_test = mpg['test'].value_counts()

# %%
count_test
# Out:
# test
# pass    128
# fall    106
# Name: count, dtype: int64

# %%
count_test.plot.bar();

# %%
count_test.plot.bar(rot = 0)
# Out:
# <Axes: xlabel='test'>

# %%
import seaborn as sns

# %%
sns.countplot(mpg, x='test', hue = 'test')
# Out:
# <Axes: xlabel='test', ylabel='count'>

# %%
sns.countplot(mpg, x='test', hue = 'test', stat ='percent')
# Out:
# <Axes: xlabel='test', ylabel='percent'>

# %%
sns.countplot(mpg, x='test', hue = 'cyl', stat ='percent')
# Out:
# <Axes: xlabel='test', ylabel='percent'>

# %%
sns.countplot(data=mpg, x="test", hue="category", stat= "percent");

# %%
mpg['grade'] = np.where(mpg.total >= 30, 'A', np.where(mpg.total >= 20, 'B', 'C'))
mpg.sample(5)
# Out:
#     manufacturer            model  displ  year  cyl       trans drv  cty  hwy  \
# 207   volkswagen              gti    2.0  1999    4  manual(m5)   f   21   29
# 86          ford  f150 pickup 4wd    4.6  1999    8    auto(l4)   4   13   16
# 131   land rover      range rover    4.2  2008    8    auto(s6)   4   12   18
# 222   volkswagen       new beetle    1.9  1999    4    auto(l4)   f   29   41
# 63         dodge      durango 4wd    5.9  1999    8    auto(l4)   4   11   15
#
#     fl    category  total  mpg_mean  test grade
# 207  r     compact   25.0      25.0  pass     B
# 86   r      pickup   14.5      14.5  fall     C
# 131  r         suv   15.0      15.0  fall     C
# 222  d  subcompact   35.0      35.0  pass     A
# 63   r         suv   13.0      13.0  fall     C

# %%
count_grade = mpg['grade'].value_counts()
count_grade
# Out:
# grade
# B    118
# C    106
# A     10
# Name: count, dtype: int64

# %%
count_grade.plot.bar(rot=0);

# %%
sns.countplot(mpg, x='grade');

# %%
sns.countplot(mpg, x='grade', hue='grade');

# %%
sns.countplot(mpg, x='grade', hue='grade', stat='percent');

# %%
mpg.grade.value_counts().sort_index().index
# Out:
# Index(['A', 'B', 'C'], dtype='object', name='grade')

# %%
mpg.grade.value_counts().sort_index().values
# Out:
# array([ 10, 118, 106])

# %%
sns.countplot(mpg, x='grade', hue='grade' , order=mpg.grade.value_counts().sort_index().index);

# %%
sns.countplot(mpg, x='grade', hue='grade', order=['A', 'B', 'C']);

# %%
np.sort(mpg.grade.unique())
# Out:
# array(['A', 'B', 'C'], dtype=object)

# %%
sns.countplot(mpg, x='grade', hue='grade', order=np.sort(mpg.grade.unique()));

# %%
s = mpg.grade
s = s.value_counts()
s = s.sort_index()
type(s)
# Out:
# pandas.core.series.Series

# %%
s = mpg.grade.value_counts().sort_index()
type(s)
s = s.sort_index()
type(s)
# Out:
# pandas.core.series.Series

# %%
s = mpg.grade.value_counts().sort_index().index

# %%
mpg['grade'] = np.where(mpg.total >= 30, 'A',
               np.where(mpg.total >= 25, 'B',
               np.where(mpg.total >= 20, 'C', 'D' )))
mpg.sample(5)
# Out:
#     manufacturer        model  displ  year  cyl       trans drv  cty  hwy fl  \
# 63         dodge  durango 4wd    5.9  1999    8    auto(l4)   4   11   15  r
# 13          audi   a4 quattro    3.1  2008    6    auto(s6)   4   17   25  p
# 218   volkswagen        jetta    2.5  2008    5  manual(m5)   f   21   29  r
# 117      hyundai      tiburon    2.0  2008    4  manual(m5)   f   20   28  r
# 167       subaru  impreza awd    2.5  1999    4  manual(m5)   4   19   26  r
#
#        category  total  mpg_mean  test grade
# 63          suv   13.0      13.0  fall     D
# 13      compact   21.0      21.0  pass     C
# 218     compact   25.0      25.0  pass     B
# 117  subcompact   24.0      24.0  pass     C
# 167  subcompact   22.5      22.5  pass     C

# %%
mpg['size'] = np.where((mpg['category'] == 'compact') |
                       (mpg['category'] == 'subcompact') |
                       (mpg['category'] == '2seater'), 'small', 'large')

# %%
mpg['size'].value_counts()
# Out:
# size
# large    147
# small     87
# Name: count, dtype: int64

# %%
mpg['size'] = np.where(mpg['category'].isin(['compact', 'subcompact', '2seater']), 'small', 'large')

# %%
mpg.sample(3)
# Out:
#         company        model  displ  year  cyl       trans drv  cty  hwy fl  \
# 178      toyota  4runner 4wd    4.7  2008    8    auto(l5)   4   14   17  r
# 117     hyundai      tiburon    2.0  2008    4  manual(m5)   f   20   28  r
# 216  volkswagen        jetta    2.0  2008    4  manual(m6)   f   21   29  p
#
#        category  total  test
# 178         suv   15.5  fail
# 117  subcompact   24.0  pass
# 216     compact   25.0  pass

# %%
mpg.sample
# Out:
# <bound method NDFrame.sample of         company   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 0          audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 1          audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 2          audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 3          audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 4          audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..          ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 229  volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 230  volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 231  volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 232  volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 233  volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#     category  total  test
# 0    compact   23.5  pass
# 1    compact   25.0  pass
# 2    compact   25.5  pass
# 3    compact   25.5  pass
# 4    compact   21.0  pass
# ..       ...    ...   ...
# 229  midsize   23.5  pass
# 230  midsize   25.0  pass
# 231  midsize   21.0  pass
# 232  midsize   22.0  pass
# 233  midsize   21.5  pass
#
# [234 rows x 13 columns]>

# %%
mpg.shape
# Out:
# (234, 13)

# %%
mpg.shape[0] * mpg.shape[1]
# Out:
# 3042

# %% [markdown]
# ### 정리하기

# %%
# 1. 패키지 로드
import pandas as pd
import numpy as np

# 2. 데이터 불러오기
mpg = pd.read_csv('data/mpg.csv')

# 3. 데이터 파악하기
mpg.shape       # 행, 열 수
mpg.head()      # 데이터 앞부분
mpg.tail()      # 데이터 뒷부분
mpg.info()      # 속성
mpg.describe()  # 요약 통계량

# 4. 변수명 바꾸기
mpg = mpg.rename(columns = {'manufacturer' : 'company'})

# 5. 파생변수 만들기
mpg['total'] = (mpg['cty'] + mpg['hwy'])/2                  # 변수 조합
mpg['test'] = np.where(mpg['total'] >= 20, 'pass', 'fail')  # 조건문 활용

# 6. 빈도 확인하기
count_test = mpg['test'].value_counts()  # 빈도표 만들기
count_test.plot.bar(rot = 0)             # 빈도 막대 그래프 만들기
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   manufacturer  234 non-null    object
#  1   model         234 non-null    object
#  2   displ         234 non-null    float64
#  3   year          234 non-null    int64
#  4   cyl           234 non-null    int64
#  5   trans         234 non-null    object
#  6   drv           234 non-null    object
#  7   cty           234 non-null    int64
#  8   hwy           234 non-null    int64
#  9   fl            234 non-null    object
#  10  category      234 non-null    object
# dtypes: float64(1), int64(4), object(6)
# memory usage: 20.2+ KB
# <Axes: xlabel='test'>

# %% [markdown]
# ## 단원 06

# %%
exam = pd.read_csv('data/exam.csv')
exam.sample(5)
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 2    3       1    45       86       78
# 5    6       2    50       89       98
# 10  11       3    65       65       65
# 13  14       4    48       87       12

# %%
exam.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       20 non-null     int64
#  1   nclass   20 non-null     int64
#  2   math     20 non-null     int64
#  3   english  20 non-null     int64
#  4   science  20 non-null     int64
# dtypes: int64(5)
# memory usage: 932.0 bytes

# %%
exam.sample(frac= .3)
# Out:
#     id  nclass  math  english  science
# 11  12       3    45       85       32
# 9   10       3    50       98       45
# 15  16       4    58       98       65
# 17  18       5    80       78       90
# 3    4       1    30       98       58
# 1    2       1    60       97       60

# %%
exam.query('nclass == 1')
# Out:
#    id  nclass  math  english  science
# 0   1       1    50       98       50
# 1   2       1    60       97       60
# 2   3       1    45       86       78
# 3   4       1    30       98       58

# %%
exam.query('nclass != 2')
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
exam.nclass == 2
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4      True
# 5      True
# 6      True
# 7      True
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# Name: nclass, dtype: bool

# %%
exam[ exam.nclass == 2]
# Out:
#    id  nclass  math  english  science
# 4   5       2    25       80       65
# 5   6       2    50       89       98
# 6   7       2    80       90       45
# 7   8       2    90       78       25

# %%
exam.query('math > 50')
# Out:
#     id  nclass  math  english  science
# 1    2       1    60       97       60
# 6    7       2    80       90       45
# 7    8       2    90       78       25
# 10  11       3    65       65       65
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
exam.query('english >= 80')
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 4    5       2    25       80       65
# 5    6       2    50       89       98
# 6    7       2    80       90       45
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 15  16       4    58       98       65
# 19  20       5    78       83       58

# %%
# 1반이면서 수학 점수가 50 점 이상인 경우
exam.query('nclass == 1 & math >= 50')
# Out:
#    id  nclass  math  english  science
# 0   1       1    50       98       50
# 1   2       1    60       97       60

# %%
exam[(exam.nclass == 1) & (exam.math >= 50)]
# Out:
#    id  nclass  math  english  science
# 0   1       1    50       98       50
# 1   2       1    60       97       60

# %%
exam.query('english < 90 | science < 60')
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 4    5       2    25       80       65
# 5    6       2    50       89       98
# 6    7       2    80       90       45
# 7    8       2    90       78       25
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 13  14       4    48       87       12
# 14  15       4    75       56       78
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
# 1, 3, 5반에 해당하면 추출
exam.query('nclass == 1 | nclass == 3 | nclass == 5')
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
a = [1, 3, 5]
1 in a
# Out:
# True

# %%
4 in a
# Out:
# False

# %%
3 in [1, 2, 3, 4]
# Out:
# True

# %%
# 1, 3, 5반에 해당하면 추출
exam.query('nclass in [1, 3, 5]')
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
exam[exam.nclass.isin([1, 3, 5])]
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
nclass1 = exam.query('nclass == 1')
nclass1
# Out:
#    id  nclass  math  english  science
# 0   1       1    50       98       50
# 1   2       1    60       97       60
# 2   3       1    45       86       78
# 3   4       1    30       98       58

# %%
nclass2 = exam.query('nclass == 2')
nclass2
# Out:
#    id  nclass  math  english  science
# 4   5       2    25       80       65
# 5   6       2    50       89       98
# 6   7       2    80       90       45
# 7   8       2    90       78       25

# %%
nclass1.math.mean()
# Out:
# np.float64(46.25)

# %%
nclass2.english.mean()
# Out:
# np.float64(84.25)

# %%
df = pd.DataFrame({'sex' : ['M', 'F', 'F', 'M'], 'country' : ['Korea', 'China', 'Japan', 'USA']})
df
# Out:
#   sex country
# 0   M   Korea
# 1   F   China
# 2   F   Japan
# 3   M     USA

# %%
# 성. 남자, 국가.Korea
df.query("sex == 'M' & country == 'Korea'")
# Out:
#   sex country
# 0   M   Korea

# %%
var = 3
exam.query('nclass == @var')
# Out:
#     id  nclass  math  english  science
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32

# %%
df = pd.DataFrame({'num_legs': [2, 4], 'num_wings': [2, 0]},
                  index=['falcon', 'dog'])
df
# Out:
#         num_legs  num_wings
# falcon         2          2
# dog            4          0

# %%
df.isin([0, 4])
# Out:
#         num_legs  num_wings
# falcon     False      False
# dog         True       True

# %%
~df.isin([0, 4])
# Out:
#         num_legs  num_wings
# falcon      True       True
# dog        False      False

# %%
exam
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 4    5       2    25       80       65
# 5    6       2    50       89       98
# 6    7       2    80       90       45
# 7    8       2    90       78       25
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
exam["math"]
# Out:
# 0     50
# 1     60
# 2     45
# 3     30
# 4     25
# 5     50
# 6     80
# 7     90
# 8     20
# 9     50
# 10    65
# 11    45
# 12    46
# 13    48
# 14    75
# 15    58
# 16    65
# 17    80
# 18    89
# 19    78
# Name: math, dtype: int64

# %%
exam.math
# Out:
# 0     50
# 1     60
# 2     45
# 3     30
# 4     25
# 5     50
# 6     80
# 7     90
# 8     20
# 9     50
# 10    65
# 11    45
# 12    46
# 13    48
# 14    75
# 15    58
# 16    65
# 17    80
# 18    89
# 19    78
# Name: math, dtype: int64

# %%
exam[["math", "english"]]
# Out:
#     math  english
# 0     50       98
# 1     60       97
# 2     45       86
# 3     30       98
# 4     25       80
# 5     50       89
# 6     80       90
# 7     90       78
# 8     20       98
# 9     50       98
# 10    65       65
# 11    45       85
# 12    46       98
# 13    48       87
# 14    75       56
# 15    58       98
# 16    65       68
# 17    80       78
# 18    89       68
# 19    78       83

# %%
exam.columns
# Out:
# Index(['id', 'nclass', 'math', 'english', 'science'], dtype='object')

# %%
exam.columns[3]
# Out:
# 'english'

# %%
exam[exam.columns[3]]
# Out:
# 0     98
# 1     97
# 2     86
# 3     98
# 4     80
# 5     89
# 6     90
# 7     78
# 8     98
# 9     98
# 10    65
# 11    85
# 12    98
# 13    87
# 14    56
# 15    98
# 16    68
# 17    78
# 18    68
# 19    83
# Name: english, dtype: int64

# %%
exam.columns[1:3]
# Out:
# Index(['nclass', 'math'], dtype='object')

# %%
exam[exam.columns[1:3]].head()
# Out:
#    nclass  math
# 0       1    50
# 1       1    60
# 2       1    45
# 3       1    30
# 4       2    25

# %%
exam[['nclass', 'math', 'english']].head()
# Out:
#    nclass  math  english
# 0       1    50       98
# 1       1    60       97
# 2       1    45       86
# 3       1    30       98
# 4       2    25       80

# %%
exam.drop(columns="math")
# Out:
#     id  nclass  english  science
# 0    1       1       98       50
# 1    2       1       97       60
# 2    3       1       86       78
# 3    4       1       98       58
# 4    5       2       80       65
# 5    6       2       89       98
# 6    7       2       90       45
# 7    8       2       78       25
# 8    9       3       98       15
# 9   10       3       98       45
# 10  11       3       65       65
# 11  12       3       85       32
# 12  13       4       98       65
# 13  14       4       87       12
# 14  15       4       56       78
# 15  16       4       98       65
# 16  17       5       68       98
# 17  18       5       78       90
# 18  19       5       68       87
# 19  20       5       83       58

# %%
exam.drop(2)
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 3    4       1    30       98       58
# 4    5       2    25       80       65
# 5    6       2    50       89       98
# 6    7       2    80       90       45
# 7    8       2    90       78       25
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
exam.drop(index = 2)
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 3    4       1    30       98       58
# 4    5       2    25       80       65
# 5    6       2    50       89       98
# 6    7       2    80       90       45
# 7    8       2    90       78       25
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
exam.drop(index = [2, 4, 6])
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 3    4       1    30       98       58
# 5    6       2    50       89       98
# 7    8       2    90       78       25
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
exam.drop(index=[2, 4, 6], axis=0)
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 3    4       1    30       98       58
# 5    6       2    50       89       98
# 7    8       2    90       78       25
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
exam.drop(labels=["math", "english"], axis=1)
# Out:
#     id  nclass  science
# 0    1       1       50
# 1    2       1       60
# 2    3       1       78
# 3    4       1       58
# 4    5       2       65
# 5    6       2       98
# 6    7       2       45
# 7    8       2       25
# 8    9       3       15
# 9   10       3       45
# 10  11       3       65
# 11  12       3       32
# 12  13       4       65
# 13  14       4       12
# 14  15       4       78
# 15  16       4       65
# 16  17       5       98
# 17  18       5       90
# 18  19       5       87
# 19  20       5       58

# %%
exam
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 4    5       2    25       80       65
# 5    6       2    50       89       98
# 6    7       2    80       90       45
# 7    8       2    90       78       25
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
exam.query('nclass == 1')
# Out:
#    id  nclass  math  english  science
# 0   1       1    50       98       50
# 1   2       1    60       97       60
# 2   3       1    45       86       78
# 3   4       1    30       98       58

# %%
exam.query('nclass == 1')['math']
# Out:
# 0    50
# 1    60
# 2    45
# 3    30
# Name: math, dtype: int64

# %%
exam.query('nclass == 1').math
# Out:
# 0    50
# 1    60
# 2    45
# 3    30
# Name: math, dtype: int64

# %%
exam.query('nclass == 1')[['math', 'english']]
# Out:
#    math  english
# 0    50       98
# 1    60       97
# 2    45       86
# 3    30       98

# %%
exam[exam.math >= 50][['id', 'math']]
# Out:
#     id  math
# 0    1    50
# 1    2    60
# 5    6    50
# 6    7    80
# 7    8    90
# 9   10    50
# 10  11    65
# 14  15    75
# 15  16    58
# 16  17    65
# 17  18    80
# 18  19    89
# 19  20    78

# %%
exam.query('math >= 50') \
    [['id', 'math']] \
    .head()
# Out:
#    id  math
# 0   1    50
# 1   2    60
# 5   6    50
# 6   7    80
# 7   8    90

# %% [markdown]
# ## 정렬

# %%
exam.sort_values('math', ascending=False).head()
# Out:
#     id  nclass  math  english  science
# 7    8       2    90       78       25
# 18  19       5    89       68       87
# 6    7       2    80       90       45
# 17  18       5    80       78       90
# 19  20       5    78       83       58

# %%
exam.sort_values(['nclass', 'math'], ascending=[True, False]).head(10)
# Out:
#     id  nclass  math  english  science
# 1    2       1    60       97       60
# 0    1       1    50       98       50
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 7    8       2    90       78       25
# 6    7       2    80       90       45
# 5    6       2    50       89       98
# 4    5       2    25       80       65
# 10  11       3    65       65       65
# 9   10       3    50       98       45

# %%
exam.sort_index()
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 4    5       2    25       80       65
# 5    6       2    50       89       98
# 6    7       2    80       90       45
# 7    8       2    90       78       25
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
exam.sort_index(ascending=False).head()
# Out:
#     id  nclass  math  english  science
# 19  20       5    78       83       58
# 18  19       5    89       68       87
# 17  18       5    80       78       90
# 16  17       5    65       68       98
# 15  16       4    58       98       65

# %%
exam.sort_index(ascending=False).head(3)
# Out:
#     id  nclass  math  english  science
# 19  20       5    78       83       58
# 18  19       5    89       68       87
# 17  18       5    80       78       90

# %%
exam.sort_index(axis=1).head()
# Out:
#    english  id  math  nclass  science
# 0       98   1    50       1       50
# 1       97   2    60       1       60
# 2       86   3    45       1       78
# 3       98   4    30       1       58
# 4       80   5    25       2       65

# %%
exam.sort_index(axis=1, ascending=False).head()
# Out:
#    science  nclass  math  id  english
# 0       50       1    50   1       98
# 1       60       1    60   2       97
# 2       78       1    45   3       86
# 3       58       1    30   4       98
# 4       65       2    25   5       80

# %% [markdown]
# ## end
